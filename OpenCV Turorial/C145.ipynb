# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('j.png', 0)

# %%
n = 5
kernel = np.ones((n, n), np.uint8)
erosion = cv2.erode(img, kernel, iterations = 1)
dilation = cv2.dilate(img,kernel,iterations = 1)

# %%
plt.rcParams["figure.figsize"] = (20, 10)
plt.subplot(141),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(142),plt.imshow(kernel),plt.title('kernel')
plt.xticks([]), plt.yticks([])
plt.subplot(143),plt.imshow(erosion),plt.title('erosion')
plt.xticks([]), plt.yticks([])
plt.subplot(144),plt.imshow(dilation),plt.title('dilation')
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))

# %%
img = cv2.imread('j_1.png', 0)

# %%
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(opening),plt.title('opening')
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))

# %%
img = cv2.imread('j_2.png', 0)

# %%
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(closing),plt.title('closing')
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))

# %%
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(gradient),plt.title('gradient')
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))

# %%
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(tophat),plt.title('tophat')
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))

# %%
blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blackhat),plt.title('blackhat')
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))
