# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('fingerprint.jpg', 3)

# %%
n = 2
kernel = np.ones((n, n), np.uint8)

# %%
erosion = cv2.erode(img, kernel, iterations = 2)
dilation = cv2.dilate(img,kernel,iterations = 2)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)
blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)

# %%
plt.subplot(),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))

# %%
plt.figure(figsize=(50,10))
plt.subplot(161),plt.imshow(erosion),plt.title('erosion', fontdict={'fontsize' : 50})
plt.xticks([]), plt.yticks([])
plt.subplot(162),plt.imshow(dilation),plt.title('dilation', fontdict={'fontsize' : 50})
plt.xticks([]), plt.yticks([])
plt.subplot(163),plt.imshow(opening),plt.title('opening', fontdict={'fontsize' : 50})
plt.xticks([]), plt.yticks([])
plt.subplot(164),plt.imshow(closing),plt.title('closing', fontdict={'fontsize' : 50})
plt.xticks([]), plt.yticks([])
plt.subplot(165), plt.imshow(tophat), plt.title('tophat', fontdict={'fontsize' : 50})
plt.xticks([]), plt.yticks([])
plt.subplot(166), plt.imshow(blackhat), plt.title('blackhat', fontdict={'fontsize' : 50})
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))
